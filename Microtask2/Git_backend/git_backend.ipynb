# %% [markdown]
# ## Microtask #2 : Git Backend
# >Create a Python script to execute Perceval via its Python interface using the Git and GitHub backends. Feel free to select any target repository.

# %% [markdown]
# We will be using chaoss [grimoirelab-elk](https://github.com/chaoss/grimoirelab-elk.git) as our target repo.

# %%
#importing required modules
from perceval.backends.core.git import Git
from datetime import datetime
from pprint import pprint

# %% [markdown]
# * The `Git` Backend class required two mandatory arguments
#     - `uri`: Url of the Git Repository in order to clone it.
#     - `gitpath`: Path where the repository will be cloned.

# %%
REPOSITORY_URL = "https://github.com/chaoss/grimoirelab-elk.git"
REPO_DIR = "./tmp/grimoirelab-elk"

# %%
# Initializing the Git backend
git_backend = Git(uri=REPOSITORY_URL,gitpath=REPO_DIR)

# %%
# Range of dates in which commits are to be fetched
from_date = datetime(2019, 1, 1)
to_date = datetime(2020, 3, 22)

# %%
repo_branches = ["master", "GeorgLink-patch-1","jgbarah-patch-1"]

# %%
# Calling fetch method
# The method retrieves from a Git repository or a log file a list of commits. 
# Commits are returned in the same order they were obtained.
range_commits = git_backend.fetch(branches=repo_branches, from_date=from_date, to_date=to_date)
range_commits_list = list(range_commits)
n_commits = len(range_commits_list)
print("NUMBER OF COMMITS: ", n_commits)
# Out:
# NUMBER OF COMMITS:  490

# %%
# Let's check the structure of one of the commits. ( picking last one in this case )
last_commit = range_commits_list[n_commits - 1]
pprint(last_commit)
# Out:
# {'backend_name': 'Git',
#  'backend_version': '0.12.0',
#  'category': 'commit',
#  'classified_fields_filtered': None,
#  'data': {'Author': 'Valerio Cosentino <valcos@bitergia.com>',
#           'AuthorDate': 'Fri Mar 20 12:35:40 2020 +0100',
#           'Commit': 'Valerio Cosentino <valcos@bitergia.com>',
#           'CommitDate': 'Fri Mar 20 12:35:40 2020 +0100',
#           'Signed-off-by': ['Valerio Cosentino <valcos@bitergia.com>'],
#           'commit': '1201f3f7242386d9f21a76fe8e2b5783fb1c8e17',
#           'files': [{'action': 'M',
#                      'added': '1',
#                      'file': 'grimoire_elk/_version.py',
#                      'indexes': ['1df687b', '82356e6'],
#                      'modes': ['100644', '100644'],
#                      'removed': '1'}],
#           'message': 'Update version number to 0.71.0\n'
#                      '\n'
#                      'Signed-off-by: Valerio Cosentino <valcos@bitergia.com>',
#           'parents': ['ec6694fa850f81a0f1f36440c246429bfdcc35d1'],
#           'refs': []},
#  'origin': 'https://github.com/chaoss/grimoirelab-elk.git',
#  'perceval_version': '0.12.24',
#  'search_fields': {'item_id': '1201f3f7242386d9f21a76fe8e2b5783fb1c8e17'},
#  'tag': 'https://github.com/chaoss/grimoirelab-elk.git',
#  'timestamp': 1584898988.284686,
#  'updated_on': 1584704140.0,
#  'uuid': 'e266f132c0f9accbdb0206a732542270caabf6fd'}

# %%
for commit in range_commits_list:
    print("COMMIT DATE: {commit_date}\nAUTHOR: {author_name}\nCOMMIT MESSAGE: {commit_message}".format(commit_date=commit["data"]["CommitDate"], author_name=commit["data"]["Author"], commit_message=commit["data"]["message"]))
    print()
# Out:
# COMMIT DATE: Wed Jan 2 14:52:20 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elk] Include stacktrace in log message
#
# This code includes the stacktrace information in the log message when fetching and
# enriching data.
#
# COMMIT DATE: Wed Jan 2 14:52:20 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [sortinghat_elk] Include stacktrace in log message for unknown exception
#
# This code includes stack trace information within the log message generated
# when an unknown exception is thrown when adding identity.
#
# COMMIT DATE: Wed Jan 2 15:04:17 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elastic] Change log message level when inserting data to ES
#
# This code changes the log message level from INFO to DEBUG when
# inserting data to ElasticSearch.
#
# COMMIT DATE: Thu Jan 10 12:27:53 2019 +0100
# AUTHOR: Santiago Dueñas <sduenas@bitergia.com>
# COMMIT MESSAGE: Update version number to 0.35.0
#
# COMMIT DATE: Wed Jan 9 21:19:01 2019 +0100
# AUTHOR: Miguel Ángel Fernández <mafesan@bitergia.com>
# COMMIT MESSAGE: [doc] Fix typos in CSV schemas
#
# Apart from the typos, all the schemas mentioning SortingHat have
# been corrected unifying how this word is written (Capital "S" and
# "H" without a blank space) to be consistent.
#
# COMMIT DATE: Thu Jan 10 13:39:45 2019 +0100
# AUTHOR: Santiago Dueñas <sduenas@bitergia.com>
# COMMIT MESSAGE: Merge pull request #537 from mafesan/fix_schema_doc
#
# [doc] Fix typos in CSV schemas
#
# COMMIT DATE: Thu Jan 10 13:40:52 2019 +0100
# AUTHOR: Santiago Dueñas <sduenas@bitergia.com>
# COMMIT MESSAGE: Update version number to 0.36.0
#
# COMMIT DATE: Wed Jan 23 16:22:08 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enrich] Allow to update enriched items
#
# This code includes the method `update_items`, which allows to
# perform update operations over an enriched index, just after
# the enrichment (and before the studies). The method must be
# redefined in the enriched connectors.
#
# COMMIT DATE: Wed Jan 23 16:22:08 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [raw] Allow to perform update operations over a raw index
#
# This code includes the method `update_items`, which allows to perform
# update operations over a raw index, just after the collection. The
# method must be redefined in the raw connectors.
#
# COMMIT DATE: Wed Jan 23 16:22:08 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [git] Remove deleted commits from raw and enriched indexes
#
# This code retrieves the commits not present in the original
# repository and delete the corresponding documents from the raw and
# enriched indexes. In a nutshell, at the end of the enrichement phase,
#  the list of current commit hashes are retrieved from the repository
# and compared with the hashes stored in the raw index. The different of
# these two sets gives the deleted commits (the ones that are stored
# but not present in the repo), which are removed from the
# raw and enriched indexes.
#
# COMMIT DATE: Wed Jan 23 16:22:08 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elastic_items] Modify `fetch` method to collect all documents
#
# This code adds a parameter to the `fetch` method to bypass the
# incremental fetch over an index. This change is needed to
# allow labeling deleted commits in Git raw data.
#
# COMMIT DATE: Wed Jan 23 16:22:08 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [git] Improve log messages when updating git commits data
#
# This code improves the log messages when executing the method `update_items`
# for Git data. Messages now includes the origin plus the name of the target
# indexes.
#
# COMMIT DATE: Wed Jan 30 09:45:23 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [raw] Enable filter raw for Gerrit data source
#
# This code allows to filter a part of the raw data for enrichment. In a
# nutshell, this is done by including the param `--filter-raw` in the
# repo within the projects.json. Later, ELK automatically creates a filter
# to retain only the data that match the value of `filter-raw`.
#
# COMMIT DATE: Wed Jan 30 09:45:23 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enrich] Allow to assign project to filtered repos
#
# This code allows to assign the project defined in the projects.json to
# the repos containing the `filter-raw` param.
#
# COMMIT DATE: Wed Jan 30 09:45:23 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elk] Set filter raw in enrich connector
#
# This code allows to set the value of the filter raw in the
# enrich connector, thus enabling to identify the project
# assigned to the repo under analysis.
#
# COMMIT DATE: Wed Jan 30 19:20:15 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elastic] Change log level message when alias is already in use
#
# This code changes the log level of the message produced when an
# alias is already in use.
#
# COMMIT DATE: Wed Feb 6 12:59:25 2019 +0100
# AUTHOR: Alberto Pérez García-Plaza <alpgarcia@bitergia.com>
# COMMIT MESSAGE: Remove alias in use check for onion
#
# This commit removes the check for `all_onion` alias that
# prevents its creation if it is already in use. This check
# only allowed to link one data source to the alias, so onion
# data for the rest of the sources remained unlinked.
#
# COMMIT DATE: Wed Feb 6 13:12:07 2019 +0100
# AUTHOR: Santiago Dueñas <sduenas@bitergia.com>
# COMMIT MESSAGE: Update version number to 0.37.0
#
# COMMIT DATE: Wed Feb 13 09:47:54 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elastic] Handle multiple filters for last date of enriched items
#
# This code allows to use multiple filters to find the last date of enriched items
# stored in an index. This change is needed to allow to select the last date of
# items fetched from the same origin with additional filters (e.g., filter-raw).
#
# COMMIT DATE: Wed Feb 13 09:47:54 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [utils] Handle `get_last_enrich` with raw filters
#
# This code allows to use the `filter-raw` param to find the last
# date of enrichment in a index. This change is needed when the
# raw items have the same origin, but include additional filters
# such as the `filter-raw`.
#
# COMMIT DATE: Wed Feb 13 09:48:27 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elastic_items] Update ES query for incremental enrichment
#
# This code changes the behaviour of the ES query to retrive
# items from the raw indexes for incremental enrichment purposes.
# In a nutshell, the query now uses a QUERY context which returns
# the items matching the query plus a score that rates how good
# the match is. However the score is not needed in ELK, thus the
# content is changed to FILTER context, which doesn't calculate
# any score.
#
# COMMIT DATE: Wed Feb 13 10:09:57 2019 +0100
# AUTHOR: Alberto Pérez García-Plaza <alpgarcia@bitergia.com>
# COMMIT MESSAGE: [studies] Add origin based enrichment in AOC
#
# These changes make the study enrich only those repos included
# in `projects.json` file instead of enriching the whole set
# of data found in the input index.
#
# COMMIT DATE: Wed Feb 13 11:45:28 2019 +0100
# AUTHOR: Santiago Dueñas <sduenas@bitergia.com>
# COMMIT MESSAGE: Update version number to 0.38.0
#
# COMMIT DATE: Mon Feb 18 10:11:33 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enrich] Add mbox_author_domain to mbox data
#
# This code includes the new field `mbox_author_domain` in the enrich data. It
# contains the email address of the sender not processed by SH.
#
# COMMIT DATE: Mon Feb 18 10:11:33 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [schema] Update mbox csv
#
# This code includes in the mbox.csv the new attribute `mbox_author_domain`, which
# contains the email domain of the sender not processed by SortingHat.
#
# COMMIT DATE: Mon Feb 18 10:11:33 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [tests] Update tests for mbox-related enrichers
#
# This code updates the tests of the mbox-related enrichers (groupsio,
# hyperkitty, nttp and pipermail) to check that the field
# `mbox_author_domain` is properly added.
#
# COMMIT DATE: Wed Feb 20 13:09:02 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [ELK] Update license info
#
# This code updates license information of the source code files in ELK.
#
# COMMIT DATE: Wed Feb 20 13:09:02 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [utils] Move e2k description to main
#
# This code moves the description of the e2k.py
# to the main method.
#
# COMMIT DATE: Wed Feb 20 13:09:02 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [utils] Move gelk description to main
#
# This code moves the description of the gelk.py
# to the main method.
#
# COMMIT DATE: Wed Feb 20 13:09:02 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [utils] Move gelk_mapping description to main
#
# This code moves the description of the
# gelk_mapping.py to the main method.
#
# COMMIT DATE: Wed Feb 20 13:09:02 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [utils] Move get_git_repos description to main
#
# This code moves the description of the get_git_repos.py
# to the main method.
#
# COMMIT DATE: Wed Feb 20 13:09:02 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [utils] Move gh2arthur description to main
#
# This code moves the description of the gh2arthur.py
# to the main method.
#
# COMMIT DATE: Wed Feb 20 13:09:02 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [utils] Move gh2k description to main
#
# This code moves the description of the gh2k.py
# to the main method.
#
# COMMIT DATE: Wed Feb 20 13:09:02 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [utils] Move index_mapping description to main
#
# This code moves the description of the index_mapping.py
# to the main method.
#
# COMMIT DATE: Wed Feb 20 13:09:02 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [utils] Move p2o description to main
#
# This code moves the description of the p2o.py
# to the main method.
#
# COMMIT DATE: Wed Feb 20 14:07:24 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enrich] Update Git references data in raw and enriched indexes
#
# This code updates the information about Git references
# of the items corresponding to commits in both raw and enriched
# indexes. The update is needed due to operations (e.g., merges
# and branch deletions) which affect the repository references
# and consequently their commits. Thus, this code aims at
# ensuring consistency between the information of the original
# Git repository and the data stored in ElasticSearch.
#
# COMMIT DATE: Wed Feb 20 14:07:24 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [schema] Update Git schema to include refs info
#
# This code updates the Git schema to include references (branches and tags)
# information, which are currently serialized as a list of keywords.
#
# COMMIT DATE: Thu Feb 21 00:13:49 2019 +0100
# AUTHOR: valerio <valcos@bitergia.com>
# COMMIT MESSAGE: Revert "[schema] Update Git schema to include refs info"
#
# This reverts commit 8b14a0b6e9559b0e8a16c39b8e124841315fa3e6.
#
# COMMIT DATE: Thu Feb 21 00:13:49 2019 +0100
# AUTHOR: valerio <valcos@bitergia.com>
# COMMIT MESSAGE: Revert "[enrich] Update Git references data in raw and enriched indexes"
#
# This reverts commit 47a38f45e81aea11d341487202ef5e91b29d0425.
#
# COMMIT DATE: Thu Feb 21 00:20:23 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enrich] Handle Perceval errors on Git repo when updating items
#
# This code allows to handle errors on Git repositories when
# updating the the content of the enriched index to remove
# commits which are not present anymore in the
# original repository.
#
# COMMIT DATE: Mon Feb 25 15:27:56 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enrich] Support enrichment of GitHub repo data
#
# This code enhances the GitHub enrich connector to handle
# the data coming from the new category `repository`. The field
# `fetched_on`, `forks_count`, `subscribers_count`
# and `stargazers_count` are added to the enriched item, they
# represent the number forks, watchers and stars of the repo.
#
# COMMIT DATE: Mon Feb 25 15:27:56 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [schema] Add schema for GitHub repo data
#
# This code documents the enriched data obtained from the information
# that summarizes a GitHub repository.
#
# COMMIT DATE: Mon Feb 25 17:25:40 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [raw] Handle filter raw for confluence
#
# This code allows to parse the filter raw information from the entries within the
# mordred projects.json.
# The projects.json should be changed to the following way:
# `"concourse-url --filter-raw=data._expandable.space:/rest/api/space/your-project"`
#
# COMMIT DATE: Tue Feb 26 18:26:33 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [raw] Handle filter raw for jira
#
# This code allows to parse the filter raw information from the entries within the
# mordred projects.json. The projects.json should be changed to the following way:
# `jira-url --filter-raw=data.fields.project.key:TARGET-PROJECT-KEY`
#
# COMMIT DATE: Tue Feb 26 18:26:33 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [tests] Add tests for parsing projects.json in Jira raw connector
#
# This code includes two tests to check that the entries in the projects.json
# for Jira sources are correctly parsed using the methods:
# - `get_arthur_params_from_url`
# - `get_p2o_params_from_url`
#
# COMMIT DATE: Thu Feb 28 17:33:49 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enrich] Update branch info in git commits
#
# This code allows to update the branch information of the JSON documents representing
# Git commits. First the list of refs is cleared in the enriched index, then
# the original repo is queried to retrieve the list of commit hashes for each branch and
# finally the obtained hashes are added to the refs attribute of the documents.
#
# COMMIT DATE: Thu Feb 28 17:33:49 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enrich] Add retry on status forcelist to ES connector
#
# This code enables the retry mechanism for some given HTTP errors. For instance,
# the 409, which may occur when executing updates and deletions by query.
#
# COMMIT DATE: Thu Feb 28 17:33:49 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [schema] Include refs attribute in git CSV
#
# This codes enhances the git schema by including the attribute `branches`,
# which represents the list of branches where a commit appears.
#
# COMMIT DATE: Mon Mar 4 09:17:15 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enrich] Add last_updated and created_on to gerrit items
#
# This code includes information about when a review was
# created and last updated. This change is needed to
# calculate time intervals via painless scripting.
#
# COMMIT DATE: Mon Mar 4 09:17:15 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [schema] Update gerrit.csv
#
# This code updates the gerrit schema with two new attributes:
# - `created_on`: when the review was created
# - `last_updated`: when the review was last updated.
#
# COMMIT DATE: Mon Mar 4 09:17:15 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enrich] Add updated field to Jira items
#
# This code includes the information about when a Jira
# issue was updated. This change is needed to calculate
# time intervals via painless scripting.
#
# COMMIT DATE: Mon Mar 4 09:17:15 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [schema] Update jira.csv
#
# This code updates the jira schema which now includes
# the attribute `updated`, used to know when an issue
# has been closed.
#
# COMMIT DATE: Tue Mar 5 13:54:10 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enriched] Handle 502 and 503 errors
#
# This code enables the retry mechanism for 502 and 503 HTTP errors. This
# change is needed to reduce the connection problems happening in remote
# instances of ElasticSearch.
#
# COMMIT DATE: Tue Mar 5 14:53:11 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [raw] Parse filters passed in the projects.json entries
#
# This code allows to parse the filters declared in the
# projects.json entries. This code applies for the Perceval
# backends that require only an URL as input parameter, for
# the others this method should be redefined.
#
# Filters are identified by the delimiter `--filter`, while the filter
# names and values are separated by `=`. For instance:
# `--filter-raw=data.product:Add-on SDK,data.component:General`
#
# COMMIT DATE: Tue Mar 5 14:53:11 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [tests] Add tests for `get_p2o_params_from_url` method
#
# This code includes tests to check whether the method
# `get_p2o_params_from_url` is able to parse filters
# defined in the projects.json entries.
#
# COMMIT DATE: Tue Mar 5 14:53:11 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [raw] Remove `get_p2o_params_from_url` from Git raw connector
#
# This code removes the method `get_p2o_params_from_url` from the
# Git raw connector. which now uses the one defined
# in the raw/elastic.py
#
# COMMIT DATE: Tue Mar 5 14:53:11 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [raw] Remove `get_p2o_params_from_url` from Gerrit raw connector
#
# This code removes the method `get_p2o_params_from_url` from the
# Gerrit raw connector. which now uses the one defined
# in the raw/elastic.py
#
# COMMIT DATE: Tue Mar 5 14:53:11 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [raw] Remove `get_p2o_params_from_url` from Askbot raw connector
#
# This code removes the method `get_p2o_params_from_url` from the
# Askbot raw connector. which now uses the one defined
# in the raw/elastic.py
#
# COMMIT DATE: Tue Mar 5 14:53:11 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [raw] Remove `get_p2o_params_from_url` from Bugzilla raw connector
#
# This code removes the method `get_p2o_params_from_url` from the
# Bugzilla raw connector. which now uses the one defined
# in the raw/elastic.py
#
# COMMIT DATE: Tue Mar 5 14:53:11 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [raw] Remove `get_p2o_params_from_url` from Confluence raw connector
#
#     This code removes the method `get_p2o_params_from_url` from the
#     Confluence raw connector. which now uses the one defined
#     in the raw/elastic.py
#
# COMMIT DATE: Tue Mar 5 14:53:11 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [raw] Remove `get_p2o_params_from_url` from Jira raw connector
#
#     This code removes the method `get_p2o_params_from_url` from the
#     Jira raw connector. which now uses the one defined
#     in the raw/elastic.py
#
# COMMIT DATE: Tue Mar 5 14:53:11 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elastic_items] Support filter on multiple attributes
#
# This code allow to support the filtering of raw data using
# more fields.
#
# COMMIT DATE: Tue Mar 5 14:53:11 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elk] Remove logic to create filters
#
# This code removes the logic to create filters which is now
# included in the elastic_items.py
#
# COMMIT DATE: Tue Mar 5 14:53:11 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enrich] Remove raw filters when getting last enriched item
#
# This code removes the raw filters from the filters used to
# identify the last enriched item. This change is needed since
# the raw filters are meaningless when applied to the enriched data.
#
# COMMIT DATE: Tue Mar 5 14:53:11 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elastic_items] Support for filter-raw-prefix
#
# This code modifies the way of filtering data based on prefixes. This
# change is needed to due the refactoring to create filters.
#
# The filter-prefix-raw can be enabled in the following way:
# `https://github.com/chaoss/grimoirelab-elk
# --filter-raw-prefix=data.files.file:README.md,data.files.file:perceval`
#
# COMMIT DATE: Wed Mar 6 08:26:37 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [raw] Prevent mapping of data.ancestors.extensions for confluence raw items
#
# This code prevents to index the data included in data.ancestors.extensions
# in order to avoid parsing_mapping_errors.
#
# COMMIT DATE: Wed Mar 6 19:28:46 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enriched] Handle hidden editors in mediawiki revisions
#
# This code handles revisions which have their editor hidden, which
# are marked as `HIDDEN_EDITOR`.
#
# COMMIT DATE: Fri Mar 8 13:06:29 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elk] Remove filter-raw-* for enrich backend
#
# This code removes the filter-raw and filter-raw-prefix which were set
# in the `enrich_backend` function but not used by the enrich backend.
#
# COMMIT DATE: Fri Mar 8 18:48:37 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elastic] Add method `delete_items`
#
# This code includes the method to delete items from an index before a given
# date. This change is needed to define retention policy data.
#
# COMMIT DATE: Fri Mar 8 18:48:37 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [utils] Set default value for variable analyzers
#
# This code allows to set a default value for the variable analyzers, used to
# initalize the elastic object.
#
# COMMIT DATE: Fri Mar 8 18:48:37 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elk] Apply data retention policy to study indexes
#
# This code allows to delete data from indexes created by studies. The
# deletion is based on the param `retentation_hours` defined in the
# setup.cfg of mordred.
#
# COMMIT DATE: Fri Mar 8 18:48:37 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enriched] Add refresh param to update_by_query and delete_by_query
#
# This code appends the refresh param to the update_by_query and
# delete_by_query calls, thus preventing retry operations and
# conflicts when updating/deleting items in the ES indexes.
#
# COMMIT DATE: Mon Mar 11 09:28:14 2019 +0100
# AUTHOR: Santiago Dueñas <sduenas@bitergia.com>
# COMMIT MESSAGE: [enrich-confluence] Add ancestors data to enriched items
#
# This patch enriches Confluence items with two new fields related
# to ancestors data.
#
# The field 'ancestors_titles' is a list with the titles of each
# ancestor, and the field 'ancestors_links' which is a list with
# the relative links to earch ancestor page.
#
# COMMIT DATE: Mon Mar 11 09:28:27 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [p2o] Add None value for param `cfg_section_name` to p2o
#
# This code includes a none value for the param `cfg_section_name`, which was
# recently added to the method `enrich_backend` in elk.py.
#
# COMMIT DATE: Mon Mar 11 14:57:45 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enrich] Add onion study to gerrit
#
# This code includes the onion study to gerrit. Thus, now an onion study
# can be defined via the setup.cfg of modred.
#
# COMMIT DATE: Mon Mar 11 14:16:58 2019 -0400
# AUTHOR: Santiago Dueñas <sduenas@bitergia.com>
# COMMIT MESSAGE: Update version number to 0.39.0
#
# COMMIT DATE: Tue Mar 12 14:13:18 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elk] Add filter raw info to enrich backend
#
# This code sets the filter raw information to the enrich backend. The filter
# raw is needed to be able to correctly assign the project value to an enriched item.
#
# COMMIT DATE: Tue Mar 12 15:37:17 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enriched] Remove `get_item_project` for bugzillarest enricher
#
# This code removes the redefinition of the `get_item_project` within
# the bugzillarest enricher. Furthermore it also adds the method
# `get_project_repository`.
#
# COMMIT DATE: Tue Mar 12 15:37:17 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enrich] Assign default project name to repos in unknown section
#
# This code assigns the default project name `Main` to the items coming
# from the repos included in the `unknown` section within the projects.json.
#
# COMMIT DATE: Tue Mar 12 15:37:17 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enriched] Update `get_project_repository` for bugzilla enricher
#
# This code updates the logic of the method `get_project_repository` within
# the bugzilla enricher which was relying on a previous version of the filter
# raw.
#
# COMMIT DATE: Tue Mar 12 15:17:58 2019 -0400
# AUTHOR: Santiago Dueñas <sduenas@bitergia.com>
# COMMIT MESSAGE: Merge pull request #577 from valeriocos/fix-project-field
#
# [elk] Handle project name for filtered repos
#
# COMMIT DATE: Tue Mar 12 15:22:00 2019 -0400
# AUTHOR: Santiago Dueñas <sduenas@bitergia.com>
# COMMIT MESSAGE: [utils] Add missing header to run scripts as Python scripts
#
# COMMIT DATE: Tue Mar 12 15:29:39 2019 -0400
# AUTHOR: Santiago Dueñas <sduenas@bitergia.com>
# COMMIT MESSAGE: Update version number to 0.40.0
#
# COMMIT DATE: Fri Mar 15 14:02:02 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [requirements] Add perceval-finos to requirements.txt
#
# This code includes the repo https://github.com/Bitergia/grimoirelab-perceval-finos
# to the requirements.txt file.
#
# COMMIT DATE: Fri Mar 15 14:02:02 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [setup] Add perceval-finos to install_requires list
#
# This code includes the dependency for the new perceval for finos
# `perceval-finos>=0.1.0`.
#
# COMMIT DATE: Fri Mar 15 14:02:02 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [utils] Add connector for finosmeetings Perceval backend
#
# This code includes a new connector to be able to fetch and
# enrich data coming from finos meetings within ELK.
#
# COMMIT DATE: Fri Mar 15 14:02:02 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [raw] Add connector for finosmeetings
#
# This code includes the connector that is in charge of storing
# the data coming from finosmeetings to the raw indexes.
#
# COMMIT DATE: Fri Mar 15 14:02:02 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enrich] Add connector for finosmeetings
#
# This code includes the connector that is in charge of enriching
# and storing the obtained data, fetched from the raw indexes containing
# finosmeetings information.
#
# COMMIT DATE: Fri Mar 15 14:02:02 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [tests] Add tests for finosmeetings
#
# This code includes tests to check that the collection and
# enrichment of finosmeetings data work properly.
#
# COMMIT DATE: Fri Mar 15 14:02:02 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [ELK] Rename finos_meetings to finosmeetings
#
# For consistency reason with the corresponding perceval backend,
# the connectors have been renamed finosmeetings.
#
# COMMIT DATE: Fri Mar 15 14:02:02 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [raw] Change mappings to convert `date` field to keyword
#
# This code changes the mapping of the attribute `date`, which in some
# cases is not a well-formed date. To handle this, the `date` field
# is mapped to a keyword, while date information is reflected to
# `date_iso_format` attribute.
#
# COMMIT DATE: Fri Mar 15 14:02:02 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enrich] Change mappings to convert `date` field to keyword
#
# This code changes the mapping of the attribute `date`, which in some
# cases is not a well-formed date. To handle this, the `date` field
# is mapped to a keyword, while date information is reflected to
# `date_iso_format` attribute.
#
# COMMIT DATE: Fri Mar 15 15:23:50 2019 -0400
# AUTHOR: Santiago Dueñas <sduenas@bitergia.com>
# COMMIT MESSAGE: Update version number to 0.41.0
#
# COMMIT DATE: Mon Mar 18 16:44:00 2019 +0100
# AUTHOR: Alberto Pérez García-Plaza <alpgarcia@bitergia.com>
# COMMIT MESSAGE: [schema] Add demography fields to Git
#
# COMMIT DATE: Tue Mar 19 20:25:43 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elastic_items] Add set_from_date method
#
# This code includes the method `set_from_date` needed
# to set the last enrich date obtained before executing the
# enrichment of the repos which (enriched) data is stored in
# the same index.
#
# COMMIT DATE: Tue Mar 19 20:25:43 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elk] Add `last_enrich_date` to enrich_backend method
#
# This code allows to pass the value of the last enrich date
# for a given index to ELK. Thus, it allows to support the
# incremental enrichment for repos which are collected
# globally but only partially enriched.
#
# COMMIT DATE: Tue Mar 19 20:25:43 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [utils] Use `last_enrich_date` for incremental enrichment
#
# This code allows to use the value of the `last_enrich_date` (obtained
# before enriching a set of repos which data is stored in the same index)
# to filter the raw items and thus driving the incremental enrichment.
#
# COMMIT DATE: Tue Mar 19 20:26:04 2019 +0100
# AUTHOR: Santiago Dueñas <sduenas@bitergia.com>
# COMMIT MESSAGE: [enrich-github] Add url field to enriched repository items
#
# This commit adds the missing URL field to GitHub repository
# items. Thus, it is aligned in data with 'issue' and 'pull_request'
# category items.
#
# COMMIT DATE: Tue Mar 19 15:35:42 2019 -0400
# AUTHOR: Santiago Dueñas <sduenas@bitergia.com>
# COMMIT MESSAGE: Update version number to 0.42.0
#
# COMMIT DATE: Wed Mar 20 13:01:22 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [utils] Change assessment of last enrich date
#
# This code changes the way how the last enrich date is calculated. If
# the enriched index is empty the last enrich date is set to None.
# Otherwise, the last enrich date is the minimum between the last
# metadata_timestamp of the enriched index before starting the TaskEnrich
# (this covers the case of repos with filter-raw) and the last
# metadata_timestamp of the items filtered by repo (this covers the case
# of a list of repos which data is shared in the same index).
#
# COMMIT DATE: Wed Mar 20 08:03:49 2019 -0400
# AUTHOR: Santiago Dueñas <sduenas@bitergia.com>
# COMMIT MESSAGE: Update version number to 0.43.0
#
# COMMIT DATE: Thu Mar 21 09:04:12 2019 +0100
# AUTHOR: Santiago Dueñas <sduenas@bitergia.com>
# COMMIT MESSAGE: [tests] Update finosmeetrings backend test to the new schema
#
# Due recent changes in FINOS Meetrings backend, some of the fields
# of the raw items have been renamed. This commit updates tests data
# to align them with the current backend.
#
# COMMIT DATE: Thu Mar 21 09:48:13 2019 -0400
# AUTHOR: Santiago Dueñas <sduenas@bitergia.com>
# COMMIT MESSAGE: Update version number to 0.44.0
#
# COMMIT DATE: Fri Mar 22 17:11:18 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enriched] Apply retry mechanism HTTP 504 errors
#
# This code allows to extend the retry mechanism to the 504 HTTP errors.
#
# COMMIT DATE: Fri Mar 22 20:38:50 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [stackexchange] Handle missing `answer_tags`
#
# This code handles enriched items not having `answer_tags` field. Thus,
# it prevents the error KeyError: 'answer_tags'.
#
# COMMIT DATE: Tue Mar 26 09:26:07 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [jira] Handle multiple type values in `release` attribute during enrichment
#
# This code adds the mapping to the Jira enriched items to avoid ES mapping
# errors on the attribute `release`, which may be wrongly detected as date.
#
# COMMIT DATE: Tue Mar 26 09:26:27 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [jira] Handle missing fields during the enrichment
#
# This code handle missing fields that are used to create the
# enriched items. In particular, it checks that the following
# fields exist:
# - issue.fields.creator
# - issue.fields.assignee
# - issue.fields.resolution
#
# COMMIT DATE: Tue Mar 26 12:08:24 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enriched] Fix `Too many dynamic script compilations` in git enrich
#
# This code fixes the ElasticSearch error `Too many dynamic script compilations`
# which occurs on the painless script used to add branch information. The script is
# modified to use the `params` attribute, that allows to compiles and stores the script
# in cache, thus avoiding compiling the script over and over.
#
# COMMIT DATE: Tue Mar 26 15:05:16 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enrich] Prevent timeout when using ElasticSearch DSL
#
# This code adds the param `retry_on_timeout` when initializing the ElasticSearch
# DSL object, thus preventing Gateway Timeout.
#
# COMMIT DATE: Tue Mar 26 18:05:05 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enriched] Add sortinghat identities info to finosmeetings
#
# This code includes the information about sortinghat identities
# in the enriched items for the finosmeetings data source.
#
# COMMIT DATE: Tue Mar 26 18:05:05 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enriched] Set project name to cm_program for finosmeetings enrich
#
# This code sets the cm_program value as project value for enriched
# items of finosmeetings.
#
# COMMIT DATE: Tue Mar 26 19:12:22 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elk] Handle filter-classified param
#
# This code allows to pass the value of the filter-classifed param
# defined in the setup.cfg to Perceval. The methods `elk.feed_backend`
# and `elastic.feed` have been refactored to handle the new
# parameter.
#
# COMMIT DATE: Tue Mar 26 19:12:22 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [meetup-enriched] Prevent to access filter-classified attributes
#
# This code includes a check to avoid accessing the filter-classified attribute
# `group.topics`, which have been removed by Perceval.
#
# COMMIT DATE: Tue Mar 26 14:40:55 2019 -0400
# AUTHOR: Santiago Dueñas <sduenas@bitergia.com>
# COMMIT MESSAGE: Update version number to 0.45.0
#
# COMMIT DATE: Wed Mar 27 14:04:33 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [finosmeetings] Change project value to cm_title
#
# This code sets the project value to the cm_title, which was
# previously cm_program.
#
# COMMIT DATE: Wed Mar 27 09:05:23 2019 -0400
# AUTHOR: Santiago Dueñas <sduenas@bitergia.com>
# COMMIT MESSAGE: Update version number to 0.46.0
#
# COMMIT DATE: Wed Mar 27 19:49:35 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [tests] Update finosmeetings test data
#
# This code updates the finosmeetings test data, which now includes the
# `cm_type` info.
#
# COMMIT DATE: Wed Mar 27 16:26:05 2019 -0400
# AUTHOR: Santiago Dueñas <sduenas@bitergia.com>
# COMMIT MESSAGE: Update version number to 0.47.0
#
# COMMIT DATE: Fri Mar 29 16:45:41 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elastic] Get all attributes in index
#
# This code includes a new method to retrieve the list of the attributes
# contained in a given index.
#
# COMMIT DATE: Fri Mar 29 16:45:41 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elastic] Refactor method `delete_items`
#
# This code moves the logic to calculate the retention date (based on the
# current time minus the hours to retain the data) to the utils file. Furthermore,
# it also improves the log messages.
#
# COMMIT DATE: Fri Mar 29 16:45:41 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elk] Store identities in use in dedicated index
#
# This code populates the index `grimoirelab-identities-cache`
# with information about the unique identities seen in the
# enriched indexes. Every unique identity identifier is stored
# in the index together with the time when it was last seen.
# For every enrich iteration, the last seen time is refreshed
# in case the unique identity appears again.
#
# COMMIT DATE: Fri Mar 29 16:45:41 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elk] Retain identities based on identities index data
#
# This code allows to delete unique identities in SortingHat
# based on the information contained in the grimoirelab-identities-cache
# index. Given the retention time param, the date before which
# an identity should be removed is calculated and used to
# retrieve the list of unique identifiers contained in the identities
# index. The obtained identitfiers are finally used to call
# the sortinghat command to delete unique identities.
#
# COMMIT DATE: Fri Mar 29 16:45:41 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [sortinghat_gelk] Add method to remove unique identities
#
# This code includes the method `remove_unique_identity`, which
# allows to remove a unique identity from SortingHat. In case,
# the identity doesn't exist, the exception is handled and logged.
#
# COMMIT DATE: Fri Mar 29 16:45:41 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [utils] Add param mapping to `get_elastic`
#
# This code adds the param `mapping` to the function `get_elastic`.
# This change is needed to allow passing the Mapping object to
# the elastic instance needed to create the corresponding
# index with the desired mapping.
#
# COMMIT DATE: Fri Mar 29 16:45:41 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enriched] Add function `get_diff_current_date` to utils
#
# This code includes the new function `get_diff_current_date` to
# calculate the time minus the number of minutes to apply the
# data retention policy. The new method is used to delete items from
# the indexes and the sortinghat identities included into them.
#
# COMMIT DATE: Fri Mar 29 16:45:41 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elk] Fix docstring in `do_studies` method
#
# This code fixes the docstring of the variable `retention_time`.
#
# COMMIT DATE: Fri Mar 29 16:45:41 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [sortinghat_gelk] Add method `remove_identity`
#
# This code add the method to remove identity from SortingHat.
#
# COMMIT DATE: Fri Mar 29 16:45:41 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [sortinghat_gelk] Add method `unique_identities`
#
# List the unique identities in SortingHat.
#
# COMMIT DATE: Fri Mar 29 16:45:41 2019 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elk] Add methods to delete identities
#
# This code includes tow methods to delete identities from SortingHat:
# - `delete_inactive_unique_identities`: delete the unique
#   identities which have not been seen during the retention time window
# - `delete_orphan_unique_identities`: delete the unique identities
#   for a given data source which are not in the IDENTITIES_INDEX
#
# COMMIT DATE: Tue Apr 2 10:03:38 2019 +0200
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enriched] Fix missing ancestor title in confluence enriched items
#
# This code handles ancestors which miss the title attribute. Tests
# have been provided accordingly.
#
# COMMIT DATE: Wed Apr 3 05:52:54 2019 +0200
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enrich-git] Handle rev-list command failures
#
# Calls for the git command `rev-list` are wrapped in try..except blocks
# to deal with production environments which use a Git version not supporting
# this command.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Wed Apr 3 15:01:48 2019 +0200
# AUTHOR: Santiago Dueñas <sduenas@bitergia.com>
# COMMIT MESSAGE: [enrich-meetup] Avoid failures when 'rsvps' field is not available
#
# Due 'rsvps' is a classified field, it might not be available
# when items are retrieved. So far, this field is considered
# as mandatory by the enricher.
#
# With this patch, ELK won't break when this field is not found.
#
# This patch also updates 'populate_identities_index' function
# to ignore those items that don't have identities. That
# happens in the case of Meetup, when 'event_host' or 'rsvps'
# are removed and no other identities are available.
#
# Signed-off-by: Santiago Dueñas <sduenas@bitergia.com>
#
# COMMIT DATE: Wed Apr 3 09:36:59 2019 -0400
# AUTHOR: Santiago Dueñas <sduenas@bitergia.com>
# COMMIT MESSAGE: Update version number to 0.48.0
#
# Signed-off-by: Santiago Dueñas <sduenas@bitergia.com>
#
# COMMIT DATE: Fri Apr 5 13:07:53 2019 +0200
# AUTHOR: Alberto Pérez García-Plaza <alpgarcia@bitergia.com>
# COMMIT MESSAGE: Update row with missing aggregatable value
#
# Signed-off-by: Alberto Pérez García-Plaza <alpgarcia@bitergia.com>
#
# COMMIT DATE: Fri Apr 5 15:18:20 2019 +0200
# AUTHOR: Daniel Izquierdo Cortazar <dicortazar@gmail.com>
# COMMIT MESSAGE: Merge pull request #603 from chaoss/alpgarcia-add-mising-cell
#
# Update row with missing aggregatable value
#
# COMMIT DATE: Mon Apr 8 18:08:23 2019 +0200
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enriched-git] Fix handling rev-list command error
#
# The try..except block including the rev-list call in the
# method `add_commit_branches` is extended since the call
# returns a generator, thus the result of the call is
# calculated afterwards.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Tue Apr 9 08:47:39 2019 +0200
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elk] Handle empty sh uuid attributes
#
# This code allows to ignore the uuid attributes which contain
# empty values, thus avoiding ES errors when inserting items
# with empty `_id`.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Tue Apr 9 15:08:18 2019 +0200
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enriched-gerrit] Use grimoirelab-toolkit calls
#
# This code replaces datetime, time and dateutil.parser calls to equivalent
# calls of grimoirelab-toolkit, thus reducing possible point of failures due
# to duplicate code.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Tue Apr 9 17:56:40 2019 +0200
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elastic_items] Handle commas in filter-raw
#
# This code allows to handle commas defined in the values of the filter-raw param
# within the projects.json. To achive this, the split match is changed to include
# a regular expression which includes the str `data.` and any blank char between
# the comma and the str.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Thu Apr 11 13:59:30 2019 +0200
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enriched-jira] Add comments to enriched index
#
# This code includes Jira comments to the enriched index. To do
# this, changes have been made to allow the cohesistance of both
# comments and issues in the same index, following an approach
# similar to meetup and stackexchange enrichers. Thus, enriched
# issues and commits have different ids, the former is the issue
# ids, while the latter is a str concatenating the issue id and
# the comment id.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Thu Apr 11 17:20:04 2019 +0200
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elastic] Check presence of `properties` in mappings
#
# This code checks the presence of the attribute `properties`
# in an enriched index. This check is needed to avoid errors
# when extracting properties from empty indexes.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Thu Apr 11 17:54:08 2019 +0200
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elastic_items] Add method `set_projects_json_repo`
#
# This code includes the method `set_projects_json_repo` to
# the elastic_items which allows to store the repo in the
# projects.json currently analyzed. This change is needed
# to simplify the logic to assign the project declared
# in the projects.json to the repository.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Thu Apr 11 17:54:08 2019 +0200
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elk] Set value of `projects_json_repo` during collection
#
# This code sets the value of projects_json_repo during the
# collection phase (`feed_backend` function). This change
# allows to know which repo url (declared in the projects.json)
# is being currently analyzed, thus it simplifies the mapping
# between the project declared in the projects.json and the
# repo included in it.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Thu Apr 11 17:54:08 2019 +0200
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elk] Set value of `projects_json_repo` during enrichment
#
# This code sets the value of projects_json_repo during the
# enrichment phase (`enrich_backend` function). This change
# allows to know which repo url (declared in the projects.json)
# is being currently analyzed, thus it simplifies the mapping
# between the project declared in the projects.json and the
# repo included in it.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Thu Apr 11 17:54:08 2019 +0200
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enriched-enrich] Refactor `find_item_project` method
#
# This code refactors the logic of the method `find_item_project`,
# which now relies on the variable `projects_json_repo` (containing
# the repo url declared in the projects.json currently processed).
# The project is identified by using the data source name plus the
# value of `projects_json_repo`. In case the projects_json_repo is
# None, the previous logic is used.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Thu Apr 11 18:27:08 2019 +0200
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [raw-jira] Update raw mapping to avoid immense term errors
#
# This code modifies the raw mappings to handle comment bodies
# longer than the maximum length allowed for keywords. Thus,
# comment bodies are mapped as text.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Thu Apr 11 14:06:59 2019 -0400
# AUTHOR: Santiago Dueñas <sduenas@bitergia.com>
# COMMIT MESSAGE: Update version number to 0.49.0
#
# Signed-off-by: Santiago Dueñas <sduenas@bitergia.com>
#
# COMMIT DATE: Fri Apr 19 19:26:42 2019 +0200
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enriched-utils] Fix last enrich date calculation
#
# This PR fixes the last enrich date calculation. The
# previous logic was calculating the minimum value between
# the last enrich global date (the one obtained before
# starting the enrichment process for all repos of a
# given data source) and the last enrich date for
# items of a given origin. If the latter date was
# empty (i.e., no items of that origin in the index), the
# last enrich date was set to the last enrich global
# date, thus only the items of the origin with a timestamp
# greater than the last enrich global date where
# processed. Now the last enrich date is set None if no
# items for a given origin are present in the enriched index.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Fri Apr 19 19:26:42 2019 +0200
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enriched-utils] Add filter raw text to retrive last enrich date
#
# This code includes the text representation (taken from the projects.json)
# of the filter raw to the filters used to retrieve the last enrich date.
# In a nutshell, this new filter allows to identify the last enrich date
# of the items relying on the filter-raw param which were missing before a
# clear correspondence with the raw items, thus making impossible to
# retrieve the correct last enrich date in case of failures during the
# enrichment process.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Fri Apr 19 19:26:42 2019 +0200
# ...
# `plainTextBugTrackerMarkdown`. The obtained text is processed
# to strip out code parts using the endpoint `code`, the text
# left is passed to the endpoints `sentiment` and `emotion`,
# which are used to derive sentiment and emotion labels for
# the input text. The labels collected are saved in the
# corresponding item on the attributes `feeling_sentiment` and
# `feeling_emotion`. Furthermore, also the attributes
# `has_sentiment = 1` and `has_emotion = 1` are added to the
# item to prevent the recalculation of feeling study for
# items already analysed.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Thu Feb 20 18:46:46 2020 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [github2] Add support for feeling study
#
# This code provides support for the feeling study. It
# can be enabled with the setup.cfg of mordred as follows:
# ```
# [github2]
# api-token = ...
# raw_index = github_chaoss_crossminer
# enriched_index = github_chaoss_crossminer_enriched
# sleep-for-rate = true
# no-archive = true
# studies = [enrich_feelings]
#
# [enrich_feelings]
# attributes = [title, body]
# nlp_rest_url = http://localhost:2901
# ```
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Thu Feb 20 18:46:46 2020 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [tests] Move httpretty to requirements_tests
#
# This code moves the package httpretty to the requirements
# needed to run the tests.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Thu Feb 20 18:46:46 2020 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [tests] Stop loop when finding a target study
#
# This code adds a break instruction when the target
# study is found, thus improving the efficiency of
# the testing code.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Sun Feb 23 18:09:16 2020 +0100
# AUTHOR: Venu Vardhan Reddy Tekula <venuvardhanreddytekula8@gmail.com>
# COMMIT MESSAGE: Update README.md
#
# This commit adds the images for the test
# configurations for grimoirelab-elk in PyCharm.
#
# Signed-off-by: Venu Vardhan Reddy Tekula <venuvardhanreddytekula8@gmail.com>
#
# COMMIT DATE: Mon Feb 24 15:19:45 2020 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [grimoire_elk] Support for Docker dependencies analysis
#
# This code includes the support for Docker dependencies analysis
# extracted from graal using Jadolint.
#
# The data can be collected by modifying the setup.cfg and
# projects.json, as follows:
#     ```
#     [dockerdeps]
#     raw_index = dockerdeps_chaoss
#     enriched_index = dockerdeps_chaoss_enrich
#     category = code_dependencies_jadolint
#     exec-path = ./jadolint.jar
#     in-paths = []Dockerfile, Dockerfile-full, Dockerfile-secured, Dockerfile-factory, Dockerfile-installed]
#     ```
#
#     ```
#     "dockerdeps": [
#        "https://github.com/chaoss/grimoirelab"
#     ],
#     ```
#
#     Tests have been added accordingly.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Mon Feb 24 15:19:45 2020 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [grimoire_elk] Support for Docker smells analysis
#
#     This code includes the support for Docker smells analysis
#     extracted from graal using Jadolint.
#
#     The data can be collected by modifying the setup.cfg and
#     projects.json, as follows:
#     ```
#     [dockersmells]
#     raw_index = dockersmells_chaoss
#     enriched_index = dockersmells_chaoss_enrich
#     category = code_quality_jadolint
#     exec-path = .../jadolint.jar
#     in-paths = [Dockerfile, Dockerfile-full, Dockerfile-secured, Dockerfile-factory, Dockerfile-installed]
#     ```
#
#     ```
#     "dockersmells": [
#        "https://github.com/chaoss/grimoirelab"
#     ],
#     ```
#
#     Tests have been added accordingly.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Mon Feb 24 15:19:45 2020 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [grimoire_elk] Add connectors for docker smells and deps
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Mon Feb 24 15:19:45 2020 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [schema] Add scheams for docker smells and deps
#
# This code includes the schemas describing the fields
# of the enriched indexes for docker smells and deps.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Mon Feb 24 20:29:56 2020 +0100
# AUTHOR: Florent Kaisser <contact@lille.bike>
# COMMIT MESSAGE: add "tags" field in git enriched index to get the number of releases.
#
# Signed-off-by: Florent Kaisser <contact@lille.bike>
#
# COMMIT DATE: Mon Feb 24 20:29:56 2020 +0100
# AUTHOR: Florent Kaisser <contact@lille.bike>
# COMMIT MESSAGE: add description in git schema for commit_tags field
#
# Signed-off-by: Florent Kaisser <contact@lille.bike>
#
# COMMIT DATE: Mon Feb 24 20:33:18 2020 +0100
# AUTHOR: Florent Kaisser <contact@lille.bike>
# COMMIT MESSAGE: Add additional index to compute the chronological evolution of opened
# issues and average opened time issues.
#
# For each repository and label, we start the study on repository
# creation date until today with a day interval (default). For each date
# we retrieve the number of open issue at this date by difference between
# number of opened issues and number of closed issues. In addition, we
# compute the average opened time for all issues open at this date.
#
# To differenciate by label, we compute evolution for bugs and all others
# labels (like "enhancement","good first issue" ... ), we call this
# "reduced labels". We need to use theses reduced labels because the
# complixity to compute evolution for each combinaison of labels would be
# too big. In addition, we rename "bug" label to "bugs" in reduced labels.
#
# Signed-off-by: Florent Kaisser <contact@lille.bike>
#
# COMMIT DATE: Mon Feb 24 20:33:18 2020 +0100
# AUTHOR: Florent Kaisser <contact@lille.bike>
# COMMIT MESSAGE: add schema for backlog studie
#
# Signed-off-by: Florent Kaisser <contact@lille.bike>
#
# COMMIT DATE: Tue Feb 25 13:25:22 2020 +0100
# AUTHOR: JJMerchante <jj.merchante@gmail.com>
# COMMIT MESSAGE: [github] Fix filter classified in GitHub and GitHub2 enrich
#
# This code checks if user_data, assignee_data, merged_by_data, comments_data.user_data and
# review_comments_data.user_data is in the raw item.
# In case don't exist, define default values for those fields.
#
# Signed-off-by: JJMerchante <jj.merchante@gmail.com>
#
# COMMIT DATE: Tue Feb 25 14:37:17 2020 +0100
# AUTHOR: JJMerchante <jj.merchante@gmail.com>
# COMMIT MESSAGE: [github2] Fix loading identities
#
# This code fixes the way the identities are loaded
# in the method `get_identities` to make the process
# more efficient. The problem is that the loop that
# loads the identities found in comments is executed
# for each identity type, however this loop should
# be executed just once.
#
# The fix allows to execute the aforementioned just
# once.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Tue Feb 25 15:20:57 2020 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: Update version number 0.70.0
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Thu Mar 5 09:02:14 2020 +0100
# AUTHOR: snack0verflow <f20160562@hyderabad.bits-pilani.ac.in>
# COMMIT MESSAGE: [doc] Update readme for secure elasticsearch
#
# Signed-off-by: snack0verflow <f20160562@hyderabad.bits-pilani.ac.in>
#
# COMMIT DATE: Thu Mar 5 09:03:45 2020 +0100
# AUTHOR: Willem Jiang <willem.jiang@gmail.com>
# COMMIT MESSAGE: Update the mattermost.csv to fix a format issue
#
# Signed-off-by: Willem Jiang <willem.jiang@gmail.com>
#
# COMMIT DATE: Thu Mar 5 16:19:34 2020 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [elk] Remove support for arthur
#
# This code removes the references, methods depedencies
# and config params used to fetch data from arthur. This
# change is needed since the integration with arthur will
# be implemented in a different way (as discussed in
# the roadmap).
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Fri Mar 6 15:45:10 2020 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [schema] Add project and project_1 descriptions to jenkins
#
# This code adds the descriptions of the project and
# project_1 to the jenkins schema.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Sun Mar 8 17:08:54 2020 +0100
# AUTHOR: snack0verflow <f20160562@hyderabad.bits-pilani.ac.in>
# COMMIT MESSAGE: [schema] Update field description
#
# Signed-off-by: snack0verflow <f20160562@hyderabad.bits-pilani.ac.in>
#
# COMMIT DATE: Mon Mar 9 16:08:03 2020 +0100
# AUTHOR: Quan Zhou <quan@bitergia.com>
# COMMIT MESSAGE: [enriched-gitlab] Fix repository value in issue
#
# This code fixes the 'repository' value of the issues URL.
# The api add the character '-' before '/issues/'.
#
# Tests data and the corresponding tests have been modified
# accordingly.
#
# Signed-off-by: Quan Zhou <quan@bitergia.com>
#
# COMMIT DATE: Thu Mar 12 18:52:28 2020 +0100
# AUTHOR: JJMerchante <jj.merchante@gmail.com>
# COMMIT MESSAGE: [sortinghat] Create enriched fields related to Sortinghat when it is disabled
#
# This commit includes the fields related to Sortinghat when it is disabled.
# - gender, gender_acc, org_name and bot are empty.
# - name, username and domain are obtained from the identity.
# - id and uuid are calculated with a hash of the backend, name, email and username
#
# Signed-off-by: JJMerchante <jj.merchante@gmail.com>
#
# COMMIT DATE: Thu Mar 12 18:52:28 2020 +0100
# AUTHOR: JJMerchante <jj.merchante@gmail.com>
# COMMIT MESSAGE: [github] Include fields related with sortinghat when it is disabled
#
# This commit include the fields realted with Sortinghat when it
# is disabled from the configuration.
#
# Tests have been added
#
# Signed-off-by: JJMerchante <jj.merchante@gmail.com>
#
# COMMIT DATE: Thu Mar 12 18:52:28 2020 +0100
# AUTHOR: JJMerchante <jj.merchante@gmail.com>
# COMMIT MESSAGE: [gitlab] Include fields related with sortinghat when it is disabled
#
# This commit include the fields realted with Sortinghat when it
# is disabled from the configuration.
#
# Tests have been added
#
# Signed-off-by: JJMerchante <jj.merchante@gmail.com>
#
# COMMIT DATE: Thu Mar 12 18:52:28 2020 +0100
# AUTHOR: JJMerchante <jj.merchante@gmail.com>
# COMMIT MESSAGE: [meetup] Include fields related with sortinghat when it is disabled
#
# This commit include the fields realted with Sortinghat when it
# is disabled from the configuration.
#
# Tests have been added
#
# Signed-off-by: JJMerchante <jj.merchante@gmail.com>
#
# COMMIT DATE: Thu Mar 12 18:52:28 2020 +0100
# AUTHOR: JJMerchante <jj.merchante@gmail.com>
# COMMIT MESSAGE: [git] Include fields related with sortinghat when it is disabled
#
# This commit include the fields realted with Sortinghat when it
# is disabled from the configuration.
#
# Tests have been added
#
# Signed-off-by: JJMerchante <jj.merchante@gmail.com>
#
# COMMIT DATE: Tue Mar 17 09:12:14 2020 +0100
# AUTHOR: Willem Jiang <willem.jiang@gmail.com>
# COMMIT MESSAGE: Update github_backlog.csv for a field missing
#
# Added the data on the 12 line.
#
# Signed-off-by: Willem Jiang <willem.jiang@gmail.com>
#
# COMMIT DATE: Tue Mar 17 21:28:43 2020 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [raw-gerrit] Handle long text for data.patchSets.comments.message
#
# This code allows to handle immense term exceptions due to the
# lenght of the attribute `data.patchSets.comments.message`.
#
# Tests have been modified accordingly.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Wed Mar 18 10:01:03 2020 +0100
# AUTHOR: Kshitij Gupta <kgupta3199@gmail.com>
# COMMIT MESSAGE:         modified:   tests/test_git.py
#
# Signed-off-by: Kshitij Gupta <kgupta3199@gmail.com>
#
# COMMIT DATE: Thu Mar 19 14:12:08 2020 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [grimoire_elk] Add support for multiple affiliations
#
# This code allows to store in the enriched indexes
# information of multiple affiliations. Such a data is
# stored as a list in the sortinghat-related
# attribute `<rol>_multi_org_names` (e.g., author_multi_org_names).
#
# Tests have been updated accordingly.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Thu Mar 19 14:12:08 2020 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [gerrit] Propagate multiple affiations attributes
#
# This code modifies the gerrit enriched items to include
# the fields representing multiple affiliations. This
# change is needed since the information of SH are
# copied during the enrichement of the different types
# of gerrit items (e.g., comments, approvals)
#
# Tests have been added accorndigly.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Thu Mar 19 14:12:08 2020 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [jira] Propagate multiple affiations attributes
#
# This code modifies the jira enriched items to include
# the fields representing multiple affiliations. This
# change is needed since the information of SH are
# copied during the enrichement of the different types
# of jira items.
#
# Tests have been added accorndigly.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Thu Mar 19 14:12:08 2020 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [tests] Add tests for multi_org_name fields
#
# This code updates the tests of ELK to check
# that the attributes including the affiliations
# coming from SortingHat are correctly stored
# in the enriched items.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Thu Mar 19 14:12:08 2020 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enriched-study-ceres-onion] Support for multiple affiliations
#
# This code allows to create the onion study index using the
# information contained in the `author_multi_org_names` attribute.
#
# In a nutshell, the organizations are first retrieved from this
# attribute. If no data is returned, the organizations are
# retrieved from the attribute `author_org_name`. The latter
# works like a fallback option (to ensure compatibility with
# old enriched indexes not including `author_multi_org_names`).
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Thu Mar 19 14:12:08 2020 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [enriched-mappings] Update aoc mappings
#
# This code includes the attribute `multi_org_names` in
# the mappings of the AOC studies. This change
# is needed to propage the information about the multiple
# affiliations of a single user to the study indexes.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Thu Mar 19 14:12:08 2020 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [schema] Add attribute for multi org names in git.csv
#
# This code includes a new attribute in the git.csv that
# document the field author_multi_org_names (which includes
# the several affiliations a user may have).
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Thu Mar 19 14:12:08 2020 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [schema] Add attribute for multi org names in github_issues.csv
#
# This code includes new attributes in the github_issues.csv
# that document the fields author_multi_org_names,
# assignee_multi_org_names and user_data_multi_org_names (which
# includes the several affiliations a user may have).
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Thu Mar 19 14:12:08 2020 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: [schema] Add attribute for multi org names in github_pull_requests.csv
#
# This code includes new attribute in the github_pull_requests.csv
# that document the field author_multi_org_names,
# merged_by_multi_org_names, user_data_multi_org_names (which
# includes the several affiliations a user may have).
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# COMMIT DATE: Fri Mar 20 12:35:40 2020 +0100
# AUTHOR: Valerio Cosentino <valcos@bitergia.com>
# COMMIT MESSAGE: Update version number to 0.71.0
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>

# %%
#Let us now print out Additions and Deletions over files from last 5 commits
for commit in range_commits_list[-5:]:
    print("* COMMIT MESSAGE: {commit_message}\n".format(commit_message=commit["data"]["message"]))
    for change_file in commit['data']['files']:
        print("\tFILE NAME: {file_name}\n\tADDITIONS: +{additions}\n\tDELETIONS: -{deletions}\n".format(file_name=change_file['file'], additions=change_file['added'], deletions=change_file['removed']))
# Out:
# * COMMIT MESSAGE: [enriched-mappings] Update aoc mappings
#
# This code includes the attribute `multi_org_names` in
# the mappings of the AOC studies. This change
# is needed to propage the information about the multiple
# affiliations of a single user to the study indexes.
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# 	FILE NAME: grimoire_elk/enriched/mappings/git_aoc.json
# 	ADDITIONS: +3
# 	DELETIONS: -0
#
# 	FILE NAME: grimoire_elk/enriched/mappings/git_aoc_es7.json
# 	ADDITIONS: +3
# 	DELETIONS: -0
#
# * COMMIT MESSAGE: [schema] Add attribute for multi org names in git.csv
#
# This code includes a new attribute in the git.csv that
# document the field author_multi_org_names (which includes
# the several affiliations a user may have).
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# 	FILE NAME: schema/git.csv
# 	ADDITIONS: +2
# 	DELETIONS: -1
#
# * COMMIT MESSAGE: [schema] Add attribute for multi org names in github_issues.csv
#
# This code includes new attributes in the github_issues.csv
# that document the fields author_multi_org_names,
# assignee_multi_org_names and user_data_multi_org_names (which
# includes the several affiliations a user may have).
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# 	FILE NAME: schema/github_issues.csv
# 	ADDITIONS: +4
# 	DELETIONS: -1
#
# * COMMIT MESSAGE: [schema] Add attribute for multi org names in github_pull_requests.csv
#
# This code includes new attribute in the github_pull_requests.csv
# that document the field author_multi_org_names,
# merged_by_multi_org_names, user_data_multi_org_names (which
# includes the several affiliations a user may have).
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# 	FILE NAME: schema/github_pull_requests.csv
# 	ADDITIONS: +72
# 	DELETIONS: -69
#
# * COMMIT MESSAGE: Update version number to 0.71.0
#
# Signed-off-by: Valerio Cosentino <valcos@bitergia.com>
#
# 	FILE NAME: grimoire_elk/_version.py
# 	ADDITIONS: +1
# 	DELETIONS: -1
